# %% [markdown]
# # TEXT MINING THE GREAT UNREAD
#
# ### Data Visualization Using Python - Melvin Wevers
#
# __Digital Humanities Group @ KNAW Humanities Cluster (Amsterdam)__
#
# ```
# melvinwevers (at) gmail.com
# ```
# ---
# In this workshop, we will use several visualization techniques to explore datasets, and uncover patterns in textual data.
# We will start by using Matplotlib in Python and then work on graphing in Pandas, which relies on Matplotlib.

# %% [markdown]
# First, we will load some required libraries.

# %%
#libraries
import glob
import numpy as np #we load numpy as np, so we can call the library using np instead of np
import pandas as pd

# %% [markdown]
# ---

# %% [markdown]
# ## 1. EXPLORING THE DATASET
#
# For this workshop, we will be working with the British newspaper Financial Times.
# Because of copyright restrictions, the dataset only includes the month September for the years 1939, 1966, and 1991.
#
# The following code block downloads the json files in the 'data' folder and places them in a Pandas dataframe.
# A Pandas Dataframe is a tabular structure similar to an Excel spreadsheet.
# You can do operations on the numbers and text in the dataframe.

# %%
path ='data' #here we define the path
allFiles = glob.glob(path + "/*.json")
frame = pd.DataFrame() #here we initialize a Pandas DataFrame
list_ = []
for file_ in allFiles:
    frame = pd.read_json(file_) #since the files are in json format we use read_json. Other options include read_csv
    list_.append(frame) 
df = pd.concat(list_)

# %% [markdown]
# We have now loaded the documents into a dataframe with the name 'df'.
#
# ---

# %% [markdown]
# ### Assignment 1: Exploring the dataset
# For the first assignment, we will explore the dataset.
# Use the following functions to explore the dataframe with the name 'df':
# ```
# df.head() #this shows the first lines (put a number between the parenthesis to determine how many lines)
# df.tail()
# df.shape[0] #this shows the (horizontal) size of the dataframe. Replace the 0 with 1 for vertical size.
# ```
# Make a markdown cell (with + or 'b') and note the names of the columns that contain the __text__ in the articles and the __date__ of the articles.

# %%
df.head(5)

# %%
df.tail()

# %%
df.shape[1]
# Out:
# 8

# %% [markdown]
# ### Assignment 2: Investigate cells that contain specific word(s)
#
# If you want to view cells that contain specific text (in this case Aarhus) you can use:
# ```
# df[df["text_content"].str.contains("Aarhus")]
# ```
# If you want to view the full contents of the cell use:
# ```
# pd.set_option('display.max_colwidth', -1)
# ```
# For truncation set the value -1 to the width of the column, for instance 50
#
# Replace the string with other string to get an idea of the type of articles in the dataset.

# %%
pd.set_option('display.max_colwidth', 30)

# %%
df[df["text_content"].str.contains("cup")]
# Out:
#                          _id article_dc_subject  \
# 51   FTDA_1939_0901_0004_012            article
# 57   FTDA_1939_0901_0005_002            article
# 76   FTDA_1939_0901_0006_002            article
# 91   FTDA_1939_0901_0007_001            article
# 43   FTDA_1939_0902_0004_003            article
# 76   FTDA_1939_0902_0006_002            article
# 23   FTDA_1939_0904_0002_008            article
# 55   FTDA_1939_0904_0003_017            article
# 58   FTDA_1939_0904_0004_001            article
# 26   FTDA_1939_0905_0002_009            article
# 11   FTDA_1939_0906_0001_012            article
# 20   FTDA_1939_0907_0002_003            article
# 66   FTDA_1939_0911_0003_018            article
# 13   FTDA_1939_0912_0001_014            article
# 46   FTDA_1939_0913_0003_017            article
# 47   FTDA_1939_0913_0003_018            article
# 65   FTDA_1939_0913_0004_002            article
# 66   FTDA_1939_0913_0005_001            article
# 85   FTDA_1939_0913_0005_020            article
# 69   FTDA_1939_0914_0004_011            article
# 29   FTDA_1939_0915_0002_009            article
# 80   FTDA_1939_0915_0004_012            article
# 9    FTDA_1939_0916_0001_010            article
# 13   FTDA_1939_0916_0001_014            article
# 17   FTDA_1939_0916_0001_018            article
# 49   FTDA_1939_0918_0003_001            article
# 55   FTDA_1939_0918_0003_007            article
# 93   FTDA_1939_0918_0004_009            article
# 81   FTDA_1939_0919_0004_012            article
# 2    FTDA_1939_0920_0001_003            article
# ..                       ...                ...
# 110  FTDA_1991_0927_0019_002            article
# 142  FTDA_1991_0927_0022_003            article
# 149  FTDA_1991_0927_0023_003            article
# 18   FTDA_1991_0928_0002_008            article
# 22   FTDA_1991_0928_0003_002            article
# 31   FTDA_1991_0928_0004_004            article
# 51   FTDA_1991_0928_0007_002            article
# 57   FTDA_1991_0928_0007_008            article
# 157  FTDA_1991_0928_0028_002            article
# 172  FTDA_1991_0928_0031_004            article
# 180  FTDA_1991_0928_0033_003            article
# 183  FTDA_1991_0928_0034_001            article
# 185  FTDA_1991_0928_0035_001            article
# 186  FTDA_1991_0928_0036_001            article
# 187  FTDA_1991_0928_0037_001            article
# 191  FTDA_1991_0928_0037_005            article
# 192  FTDA_1991_0928_0037_006            article
# 199  FTDA_1991_0928_0039_001            article
# 202  FTDA_1991_0928_0039_004            article
# 210  FTDA_1991_0928_0042_003            article
# 1    FTDA_1991_0930_0001_002            article
# 34   FTDA_1991_0930_0006_002            article
# 53   FTDA_1991_0930_0009_004            article
# 71   FTDA_1991_0930_0011_007            article
# 81   FTDA_1991_0930_0013_005            article
# 85   FTDA_1991_0930_0015_001            article
# 92   FTDA_1991_0930_0017_002            article
# 114  FTDA_1991_0930_0021_002            article
# 155  FTDA_1991_0930_0026_003            article
# 174  FTDA_1991_0930_0034_001            article
#
#                   article_dc_title paper_dc_date       paper_dc_title  \
# 51            City Men and Matters    1939-09-01  The Financial Times
# 57   Business Almost at Standstill    1939-09-01  The Financial Times
# 76             Kaffirs Marked down    1939-09-01  The Financial Times
# 91   Building and Equipping She...    1939-09-01  The Financial Times
# 43         Carrying on in the City    1939-09-02  The Financial Times
# 76   Multiple Classified Advert...    1939-09-02  The Financial Times
# 23       Thos. W. Ward and Triumph    1939-09-04  The Financial Times
# 55              Notrade with Enemy    1939-09-04  The Financial Times
# 58   Foreign Stocks Affected by...    1939-09-04  The Financial Times
# 26   Temporapy Rules for Share ...    1939-09-05  The Financial Times
# 11   Fair Demand for Popular In...    1939-09-06  The Financial Times
# 20         The Control of Manpower    1939-09-07  The Financial Times
# 66   Multiple Classified Advert...    1939-09-11  The Financial Times
# 13   Week Opens under Shadow of...    1939-09-12  The Financial Times
# 46      Commodity War Risk Working    1939-09-13  The Financial Times
# 47   Premier to Review Position...    1939-09-13  The Financial Times
# 65             The Financial Times    1939-09-13  The Financial Times
# 66       Clifford Motor Components    1939-09-13  The Financial Times
# 85   Multiple Classified Advert...    1939-09-13  The Financial Times
# 69   Multiple Classified Advert...    1939-09-14  The Financial Times
# 29           Stock Exchange Prices    1939-09-15  The Financial Times
# 80                 Company Notices    1939-09-15  The Financial Times
# 9                  A Malign Factor    1939-09-16  The Financial Times
# 13   Stock Markets End Week wit...    1939-09-16  The Financial Times
# 17   Multiple Classified Advert...    1939-09-16  The Financial Times
# 49   France Mobilises Her Resou...    1939-09-18  The Financial Times
# 55       Hire Purchase in War-Time    1939-09-18  The Financial Times
# 93   Multiple Classified Advert...    1939-09-18  The Financial Times
# 81   Multiple Classified Advert...    1939-09-19  The Financial Times
# 2    Multiple Classified Advert...    1939-09-20  The Financial Times
# ..                             ...           ...                  ...
# 110  Step Towards a Peace Confe...    1991-09-27  The Financial Times
# 142  Multiple Classified Advert...    1991-09-27  The Financial Times
# 149  Travis Perkins Falls 60% a...    1991-09-27  The Financial Times
# 18   Gorbachev Hopeful on Econo...    1991-09-28  The Financial Times
# 22   Moderate Arafat Praises Bu...    1991-09-28  The Financial Times
# 31   Hattersley Plans Crime Sta...    1991-09-28  The Financial Times
# 51   Britain Has Its Rental Tra...    1991-09-28  The Financial Times
# 57              Tougher at the Top    1991-09-28  The Financial Times
# 157               Bank of Scotland    1991-09-28  The Financial Times
# 172         East Berlin's New Menu    1991-09-28  The Financial Times
# 180       All Blacks Hold the Edge    1991-09-28  The Financial Times
# 183  Gloom Deepens in the Low-c...    1991-09-28  The Financial Times
# 185  Multiple Classified Advert...    1991-09-28  The Financial Times
# 186  Multiple Classified Advert...    1991-09-28  The Financial Times
# 187  Croatia's Key Battlefield:...    1991-09-28  The Financial Times
# 191  Lowering the Scarlet Standard    1991-09-28  The Financial Times
# 192  Writers Who Suffer for The...    1991-09-28  The Financial Times
# 199  The Dilemmas of a Booker J...    1991-09-28  The Financial Times
# 202              Lautrec's Lineage    1991-09-28  The Financial Times
# 210             Hippy Aristophanes    1991-09-28  The Financial Times
# 1    Major Backs Plans for Inhe...    1991-09-30  The Financial Times
# 34   Arafat Wins Backing over P...    1991-09-30  The Financial Times
# 53   Investment of Pride in Nor...    1991-09-30  The Financial Times
# 71   Mortgage Costs May Be Drop...    1991-09-30  The Financial Times
# 81   Markets Look for a Fed Ini...    1991-09-30  The Financial Times
# 85     In Search of a Broader Role    1991-09-30  The Financial Times
# 92               A Change of Gears    1991-09-30  The Financial Times
# 114                        Letters    1991-09-30  The Financial Times
# 155  Yields Show Their First Ri...    1991-09-30  The Financial Times
# 174           London Share Service    1991-09-30  The Financial Times
#
#     paper_dcterms_spatial paper_dcterms_temporal  \
# 51         National Daily         National Daily
# 57         National Daily         National Daily
# 76         National Daily         National Daily
# 91         National Daily         National Daily
# 43         National Daily         National Daily
# 76         National Daily         National Daily
# 23         National Daily         National Daily
# 55         National Daily         National Daily
# 58         National Daily         National Daily
# 26         National Daily         National Daily
# 11         National Daily         National Daily
# 20         National Daily         National Daily
# 66         National Daily         National Daily
# 13         National Daily         National Daily
# 46         National Daily         National Daily
# 47         National Daily         National Daily
# 65         National Daily         National Daily
# 66         National Daily         National Daily
# 85         National Daily         National Daily
# 69         National Daily         National Daily
# 29         National Daily         National Daily
# 80         National Daily         National Daily
# 9          National Daily         National Daily
# 13         National Daily         National Daily
# 17         National Daily         National Daily
# 49         National Daily         National Daily
# 55         National Daily         National Daily
# 93         National Daily         National Daily
# 81         National Daily         National Daily
# 2          National Daily         National Daily
# ..                    ...                    ...
# 110        National Daily         National Daily
# 142        National Daily         National Daily
# 149        National Daily         National Daily
# 18         National Daily         National Daily
# 22         National Daily         National Daily
# 31         National Daily         National Daily
# 51         National Daily         National Daily
# 57         National Daily         National Daily
# 157        National Daily         National Daily
# 172        National Daily         National Daily
# 180        National Daily         National Daily
# 183        National Daily         National Daily
# 185        National Daily         National Daily
# 186        National Daily         National Daily
# 187        National Daily         National Daily
# 191        National Daily         National Daily
# 192        National Daily         National Daily
# 199        National Daily         National Daily
# 202        National Daily         National Daily
# 210        National Daily         National Daily
# 1          National Daily         National Daily
# 34         National Daily         National Daily
# 53         National Daily         National Daily
# 71         National Daily         National Daily
# 81         National Daily         National Daily
# 85         National Daily         National Daily
# 92         National Daily         National Daily
# 114        National Daily         National Daily
# 155        National Daily         National Daily
# 174        National Daily         National Daily
#
#                       text_content
# 51   i! AY by day evacuation ha...
# 57   A complete change in the S...
# 76   Kaffirs generally opened o...
# 91   URING recent months a grea...
# 43   It was just as well that t...
# 76   VALUATIONS MADE CV S FMOR ...
# 23   ine acquisition by nTos. W...
# 55   Traders, shipowners and ot...
# 58   The following list of secu...
# 26   1Members and staffs脗路were ...
# 11   TUESDAY Evening. Equity sh...
# 20   The Control of Employment ...
# 66   I through vered for lebts ...
# 13   MONDAY Evening. The beginn...
# 46   It is understood that the ...
# 47   By our POLITICAL CORRESPON...
# 65   The Leading Journal of Fin...
# 66   The annual general meeting...
# 85   9 s,. of to he to to he be...
# 69   PERSONAL LIFE POLICIES AND...
# 29   RECORD OF YESTERDAY'S BARG...
# 80   COMPANY NOTICES COMPANY NO...
# 9    Sales to provide for the s...
# 13   FRIDAY Evening. The first ...
# 17   FURNISHED HOUSES TO LET DE...
# 49   From our PARIS CORRESPONDE...
# 55   War conditions will inevit...
# 93   EMERGENCY BUSINESS ADDRESS...
# 81   THE ASE NATIONAL BA OF THE...
# 2    FLATS AND CHAMBERS FURNISH...
# ..                             ...
# 110  From Mr Martin P Hughes. S...
# 142  hile most ban While most b...
# 149  By Peggy Hollinger TRAVIS ...
# 18   By Leyla Boulton in Moscow...
# 22   By Lamis Andoni in Algiers...
# 31   By Allson Smith LABOUR is ...
# 51   From Mr JD Gmham. Sir, Re ...
# 57   \r\n\t\t\t\t\t\t\t \r\n\t\...
# 157  Money Market Cheque Accoun...
# 172  N August 1987 the Grand Ho...
# 180  almost to a halt on Thursd...
# 183  F IT WERE cheaper to rent ...
# 185  1 I 11 bedrooi, 8 bathroom...
# 186  COUNTRY PROPERTY - I U-r T...
# 187  HESE ARE bard times for fo...
# 191  Robin Lane Fox likes his r...
# 192  RNESTO Diaz Rodri- gues is...
# 199  "YOU'RE NOT going to resig...
# 202  Before next month's Haywar...
# 210  AKE LOVE not war; flower p...
# 1    T no in b4 is to ta he th ...
# 34   By Tony Walker in Cairo, H...
# 53   Chris Tighe talks to local...
# 71   By Peter Marsh THE GOVERNM...
# 81   THE hesitant US recovery a...
# 85   I ne 1945 atom bomb attack...
# 92   HIROSHIMA PREFECTURE, wher...
# 114  US planners offer answer o...
# 155  IT had to happen. The gilt...
# 174  mwN 856.' 311. 3093 756.' ...
#
# [410 rows x 8 columns]

# %% [markdown]
# ## 2. WORKING WITH DATES
#
# If we want to study changes over time, we need a variable that indicates time.
# In this case we will use the 'date' column.
# There are two main approaches if you want to work with dates.

# %% [markdown]
# ### 2.1. Setting the date column as an index
# For this approach, we convert the column with the dates to an index based on dates.
# By default the index is a list of number linked to each row.
# We can then use this index as a variable.

# %%
#the function to_datetime tells Pandas that the column includes dates
df['paper_dc_date'] = pd.to_datetime(df['paper_dc_date']) 

#the function set_index tells Pandas to use the 'date' column as the index. 
#By specifying the drop parameter as 'False' we tell Pandas to keep the original column with the dates. 
#Otherwise this column is removed. Since we need it for the Second Approach, we want to keep it. 
df = df.set_index(['paper_dc_date'], drop=False)

# %% [markdown]
# __Inspect the dataframe to see what has changed__

# %% [markdown]
# ---

# %% [markdown]
# ### 2.2. Turning elements of the dates in separate variables
# For this approach we will take elements from the date column and turn those into separate variables.
# For instance, turn the number of the month into a separate column, and the day of the week.
# The following line of code creates a column 'day' with the numbers of the day in the month.
# ```
# df['day'] = df['paper_dc_date'].dt.day
# ```
#
# ---

# %% [markdown]
# ### Assignment 3: Making columns with date information
# Make new columns that contains the number of the week, month, and year.
# Which of these columns is redundant for our dataset?

# %%
df['year'] = df['paper_dc_date'].dt.year
df.head(50)
# Out:
#                                    _id article_dc_subject  \
# paper_dc_date
# 1939-09-01     FTDA_1939_0901_0001_001            article
# 1939-09-01     FTDA_1939_0901_0001_002            article
# 1939-09-01     FTDA_1939_0901_0001_003            article
# 1939-09-01     FTDA_1939_0901_0001_004            article
# 1939-09-01     FTDA_1939_0901_0001_005            article
# 1939-09-01     FTDA_1939_0901_0001_006            article
# 1939-09-01     FTDA_1939_0901_0001_007            article
# 1939-09-01     FTDA_1939_0901_0001_008            article
# 1939-09-01     FTDA_1939_0901_0001_009            article
# 1939-09-01     FTDA_1939_0901_0001_010            article
# 1939-09-01     FTDA_1939_0901_0001_011            article
# 1939-09-01     FTDA_1939_0901_0002_001            article
# 1939-09-01     FTDA_1939_0901_0002_002            article
# 1939-09-01     FTDA_1939_0901_0002_003            article
# 1939-09-01     FTDA_1939_0901_0002_004            article
# 1939-09-01     FTDA_1939_0901_0002_005            article
# 1939-09-01     FTDA_1939_0901_0002_006            article
# 1939-09-01     FTDA_1939_0901_0002_007            article
# 1939-09-01     FTDA_1939_0901_0002_008            article
# 1939-09-01     FTDA_1939_0901_0003_001            article
# 1939-09-01     FTDA_1939_0901_0003_002            article
# 1939-09-01     FTDA_1939_0901_0003_003            article
# 1939-09-01     FTDA_1939_0901_0003_004            article
# 1939-09-01     FTDA_1939_0901_0003_005            article
# 1939-09-01     FTDA_1939_0901_0003_006            article
# 1939-09-01     FTDA_1939_0901_0003_007            article
# 1939-09-01     FTDA_1939_0901_0003_008            article
# 1939-09-01     FTDA_1939_0901_0003_009            article
# 1939-09-01     FTDA_1939_0901_0003_010            article
# 1939-09-01     FTDA_1939_0901_0003_011            article
# 1939-09-01     FTDA_1939_0901_0003_012            article
# 1939-09-01     FTDA_1939_0901_0003_013            article
# 1939-09-01     FTDA_1939_0901_0003_014            article
# 1939-09-01     FTDA_1939_0901_0003_015            article
# 1939-09-01     FTDA_1939_0901_0003_016            article
# 1939-09-01     FTDA_1939_0901_0003_017            article
# 1939-09-01     FTDA_1939_0901_0003_018            article
# 1939-09-01     FTDA_1939_0901_0003_019            article
# 1939-09-01     FTDA_1939_0901_0003_020            article
# 1939-09-01     FTDA_1939_0901_0003_021            article
# 1939-09-01     FTDA_1939_0901_0004_001            article
# 1939-09-01     FTDA_1939_0901_0004_002            article
# 1939-09-01     FTDA_1939_0901_0004_003            article
# 1939-09-01     FTDA_1939_0901_0004_004            article
# 1939-09-01     FTDA_1939_0901_0004_005            article
# 1939-09-01     FTDA_1939_0901_0004_006            article
# 1939-09-01     FTDA_1939_0901_0004_007            article
# 1939-09-01     FTDA_1939_0901_0004_008            article
# 1939-09-01     FTDA_1939_0901_0004_009            article
# 1939-09-01     FTDA_1939_0901_0004_010            article
#
#                             article_dc_title paper_dc_date  \
# paper_dc_date
# 1939-09-01      Fuller Horsey Sons & Cassell    1939-09-01
# 1939-09-01            Index and News Summary    1939-09-01
# 1939-09-01                 Gold Again Dearer    1939-09-01
# 1939-09-01               The Financial Times    1939-09-01
# 1939-09-01     Rise in British Funds Seve...    1939-09-01
# 1939-09-01              Gilt-Edged Fluctuate    1939-09-01
# 1939-09-01           China Coupon Due To-Day    1939-09-01
# 1939-09-01     Quotations Lowered as Prec...    1939-09-01
# 1939-09-01     Blades, East & Blades, Lim...    1939-09-01
# 1939-09-01             Why "House" is Closed    1939-09-01
# 1939-09-01                 Capital Increases    1939-09-01
# 1939-09-01             London Closing Prices    1939-09-01
# 1939-09-01                      Option Rates    1939-09-01
# 1939-09-01                 Unit Trust Prices    1939-09-01
# 1939-09-01     Quotations Show Little Change    1939-09-01
# 1939-09-01     Prices of Issues Made in p...    1939-09-01
# 1939-09-01     Rubber Shares Ease in Quie...    1939-09-01
# 1939-09-01               Transfer of Offices    1939-09-01
# 1939-09-01                       White Horse    1939-09-01
# 1939-09-01     International Fears Oversh...    1939-09-01
# 1939-09-01     "Financial Times" New York...    1939-09-01
# 1939-09-01     Bonds芒聙聰Government and Mun...    1939-09-01
# 1939-09-01     Bonds芒聙聰Railroad and Indus...    1939-09-01
# 1939-09-01                  Trusts and Banks    1939-09-01
# 1939-09-01                Most Active Stocks    1939-09-01
# 1939-09-01       Closing Averages and Volume    1939-09-01
# 1939-09-01           Hourly Volume & Indices    1939-09-01
# 1939-09-01                    Day's Dealings    1939-09-01
# 1939-09-01                   Rails Resistant    1939-09-01
# 1939-09-01                       Curb Prices    1939-09-01
# 1939-09-01             U. S. Raw Silk Market    1939-09-01
# 1939-09-01                  Hong Kong Market    1939-09-01
# 1939-09-01     Selling of Gold Shares at ...    1939-09-01
# 1939-09-01                  Vancouver Prices    1939-09-01
# 1939-09-01            Foreign Exchange Rates    1939-09-01
# 1939-09-01            The Commercial Markets    1939-09-01
# 1939-09-01       Afternoon Check to Business    1939-09-01
# 1939-09-01          Bell Telephone of Canada    1939-09-01
# 1939-09-01                   To-Day's Events    1939-09-01
# 1939-09-01                           Prunier    1939-09-01
# 1939-09-01               The Financial Times    1939-09-01
# 1939-09-01                 Closing the House    1939-09-01
# 1939-09-01     Currency Demands & the Gol...    1939-09-01
# 1939-09-01      The Depreciation of Sterling    1939-09-01
# 1939-09-01              Prudential Assurance    1939-09-01
# 1939-09-01                     Ketton Cement    1939-09-01
# 1939-09-01            Staveley Coal and Iron    1939-09-01
# 1939-09-01                 Broken Hill South    1939-09-01
# 1939-09-01                       E. W. Tarry    1939-09-01
# 1939-09-01                Edinburgh Shipping    1939-09-01
#
#                     paper_dc_title paper_dcterms_spatial  \
# paper_dc_date
# 1939-09-01     The Financial Times        National Daily
# 1939-09-01     The Financial Times        National Daily
# 1939-09-01     The Financial Times        National Daily
# 1939-09-01     The Financial Times        National Daily
# 1939-09-01     The Financial Times        National Daily
# 1939-09-01     The Financial Times        National Daily
# 1939-09-01     The Financial Times        National Daily
# 1939-09-01     The Financial Times        National Daily
# 1939-09-01     The Financial Times        National Daily
# 1939-09-01     The Financial Times        National Daily
# 1939-09-01     The Financial Times        National Daily
# 1939-09-01     The Financial Times        National Daily
# 1939-09-01     The Financial Times        National Daily
# 1939-09-01     The Financial Times        National Daily
# 1939-09-01     The Financial Times        National Daily
# 1939-09-01     The Financial Times        National Daily
# 1939-09-01     The Financial Times        National Daily
# 1939-09-01     The Financial Times        National Daily
# 1939-09-01     The Financial Times        National Daily
# 1939-09-01     The Financial Times        National Daily
# 1939-09-01     The Financial Times        National Daily
# 1939-09-01     The Financial Times        National Daily
# 1939-09-01     The Financial Times        National Daily
# 1939-09-01     The Financial Times        National Daily
# 1939-09-01     The Financial Times        National Daily
# 1939-09-01     The Financial Times        National Daily
# 1939-09-01     The Financial Times        National Daily
# 1939-09-01     The Financial Times        National Daily
# 1939-09-01     The Financial Times        National Daily
# 1939-09-01     The Financial Times        National Daily
# 1939-09-01     The Financial Times        National Daily
# 1939-09-01     The Financial Times        National Daily
# 1939-09-01     The Financial Times        National Daily
# 1939-09-01     The Financial Times        National Daily
# 1939-09-01     The Financial Times        National Daily
# 1939-09-01     The Financial Times        National Daily
# 1939-09-01     The Financial Times        National Daily
# 1939-09-01     The Financial Times        National Daily
# 1939-09-01     The Financial Times        National Daily
# 1939-09-01     The Financial Times        National Daily
# 1939-09-01     The Financial Times        National Daily
# 1939-09-01     The Financial Times        National Daily
# 1939-09-01     The Financial Times        National Daily
# 1939-09-01     The Financial Times        National Daily
# 1939-09-01     The Financial Times        National Daily
# 1939-09-01     The Financial Times        National Daily
# 1939-09-01     The Financial Times        National Daily
# 1939-09-01     The Financial Times        National Daily
# 1939-09-01     The Financial Times        National Daily
# 1939-09-01     The Financial Times        National Daily
#
#               paper_dcterms_temporal                   text_content  day  \
# paper_dc_date
# 1939-09-01            National Daily  -ESTABLISHED 1807- FULLER ...    1
# 1939-09-01            National Daily  ELL V M脗路1 f.Z Pag America...    1
# 1939-09-01            National Daily  Bank Rate 4 per cent., 24t...    1
# 1939-09-01            National Daily  CITY EDITION LARGEST CIRCU...    1
# 1939-09-01            National Daily  Setember . October Contang...    1
# 1939-09-01            National Daily  Gilt-edged securities open...    1
# 1939-09-01            National Daily  All considerations of busi...    1
# 1939-09-01            National Daily  THURSDAY Evening. The Indu...    1
# 1939-09-01            National Daily  COMPANY PRINTING All Speci...    1
# 1939-09-01            National Daily  *t s s d d r s y 0 s d 3. ...    1
# 1939-09-01            National Daily  Nominal capital, of the fo...    1
# 1939-09-01            National Daily  GOVERN3MENT STOCKS prP Pri...    1
# 1939-09-01            National Daily  CAUl. OI L nents CL LOl me...    1
# 1939-09-01            National Daily  - 31st Aug. MUNICIPAL AND ...    1
# 1939-09-01            National Daily  Business in the Tea share ...    1
# 1939-09-01            National Daily  Insue' 31st Aug. o Rise pr...    1
# 1939-09-01            National Daily  THURSDAY Evening. The Rubb...    1
# 1939-09-01            National Daily  New Consolidated Gold Fiel...    1
# 1939-09-01            National Daily  Ask for WHITE HORSE as a m...    1
# 1939-09-01            National Daily  G0OOD INDUSTRIAL NEWS NEGL...    1
# 1939-09-01            National Daily  Eng. equfv. 59816 19518 41...    1
# 1939-09-01            National Daily  En 316t -?ln.3 13t 30th | ...    1
# 1939-09-01            National Daily  27 . 41% 19 1012 11114 9 ....    1
# 1939-09-01            National Daily  The following are the pric...    1
# 1939-09-01            National Daily  All the most active Wall S...    1
# 1939-09-01            National Daily  bonds Hails Ind1us. Utit V...    1
# 1939-09-01            National Daily  1t Au. duail - Trad tiliti...    1
# 1939-09-01            National Daily  Stock Exchange- 31st Augus...    1
# 1939-09-01            National Daily  NEW YORK, 31st August. The...    1
# 1939-09-01            National Daily  Closing bid I arn'd *Kng. ...    1
# 1939-09-01            National Daily  31st Aug. JOth Aug. 29th A...    1
# 1939-09-01            National Daily  A cable from Croucher and ...    1
# 1939-09-01            National Daily  FROM OUR OWN CORRESPONDENT...    1
# 1939-09-01            National Daily  *ing.I Stocks and divs. 31...    1
# 1939-09-01            National Daily  - 1 .rmint 31st Aug. 30th ...    1
# 1939-09-01            National Daily  WHEAT VERY STEADY CHICAGO,...    1
# 1939-09-01            National Daily  THUKR DAY Evening. News th...    1
# 1939-09-01            National Daily  A quarterly dividend of $2...    1
# 1939-09-01            National Daily  COMPANY MEETINGS- Armstron...    1
# 1939-09-01            National Daily  TH FAMnOUS RISH RSTAUmANT ...    1
# 1939-09-01            National Daily  BSTABLISHED 1888 Incorpora...    1
# 1939-09-01            National Daily  Yesterday's announcement t...    1
# 1939-09-01            National Daily  The decision to decontrol ...    1
# 1939-09-01            National Daily  Yesterday's fall in sterli...    1
# 1939-09-01            National Daily  The decision of the direct...    1
# 1939-09-01            National Daily  There is no indication in ...    1
# 1939-09-01            National Daily  Tne reduction in the final...    1
# 1939-09-01            National Daily  A further decline in the p...    1
# 1939-09-01            National Daily  Earnings last year of E. W...    1
# 1939-09-01            National Daily  A descending level of earn...    1
#
#                year  month  week
# paper_dc_date
# 1939-09-01     1939      9    35
# 1939-09-01     1939      9    35
# 1939-09-01     1939      9    35
# 1939-09-01     1939      9    35
# 1939-09-01     1939      9    35
# 1939-09-01     1939      9    35
# 1939-09-01     1939      9    35
# 1939-09-01     1939      9    35
# 1939-09-01     1939      9    35
# 1939-09-01     1939      9    35
# 1939-09-01     1939      9    35
# 1939-09-01     1939      9    35
# 1939-09-01     1939      9    35
# 1939-09-01     1939      9    35
# 1939-09-01     1939      9    35
# 1939-09-01     1939      9    35
# 1939-09-01     1939      9    35
# 1939-09-01     1939      9    35
# 1939-09-01     1939      9    35
# 1939-09-01     1939      9    35
# 1939-09-01     1939      9    35
# 1939-09-01     1939      9    35
# 1939-09-01     1939      9    35
# 1939-09-01     1939      9    35
# 1939-09-01     1939      9    35
# 1939-09-01     1939      9    35
# 1939-09-01     1939      9    35
# 1939-09-01     1939      9    35
# 1939-09-01     1939      9    35
# 1939-09-01     1939      9    35
# 1939-09-01     1939      9    35
# 1939-09-01     1939      9    35
# 1939-09-01     1939      9    35
# 1939-09-01     1939      9    35
# 1939-09-01     1939      9    35
# 1939-09-01     1939      9    35
# 1939-09-01     1939      9    35
# 1939-09-01     1939      9    35
# 1939-09-01     1939      9    35
# 1939-09-01     1939      9    35
# 1939-09-01     1939      9    35
# 1939-09-01     1939      9    35
# 1939-09-01     1939      9    35
# 1939-09-01     1939      9    35
# 1939-09-01     1939      9    35
# 1939-09-01     1939      9    35
# 1939-09-01     1939      9    35
# 1939-09-01     1939      9    35
# 1939-09-01     1939      9    35
# 1939-09-01     1939      9    35

# %%
df['week'].value_counts()
# Out:
# 38    3435
# 37    3391
# 39    3199
# 36    3153
# 35     791
# 40     185
# Name: week, dtype: int64

# %% [markdown]
# We can now use both the index and the columns with date information to plot graphs on a temporal axis.
# But before we start doing this we need to generate some additional statistics about the dataset that we can plot over time.

# %% [markdown]
# ---

# %% [markdown]
# ## 3. GENERATING TEXT STATISTICS
#
# For this workshop, we will generate some basic descriptive statistics about the articles in the Financial Times.
# We will use this information to generate the graphs in the remainder of this workshop.

# %%
#calculate length of articles
df['article_length'] = df['text_content'].str.len()

#calculate mean length per day
df['mean_article_length'] = df['article_length'].groupby(pd.TimeGrouper('D')).aggregate(np.mean).dropna()

# %%
#calculate number of words
def word_counter(row):
    tokens = row["text_content"].split(" ")
    return len(tokens)

df["number_of_words"] = df.apply(word_counter, axis=1)

#calculate mean number of words per day
df['mean_number_of_words'] = df['number_of_words'].groupby(pd.TimeGrouper('D')).aggregate(np.mean).dropna()

# %% [markdown]
# __Inspect the new columns in the dataframe__

# %% [markdown]
# ---

# %% [markdown]
# ## 4. VISUALIZING DESCRIPTIVE TEXT STATISTICS

# %% [markdown]
# For plotting we are going to be using Matplotlib and the Pandas extension build on this library.
#
# We'll start by import the matplotlib library into python.

# %%
#this imports the library as plt
import matplotlib.pyplot as plt 
#this tells Jupyter Notebook to show the graph inside the notebook
# %matplotlib inline

# %%
plt.plot()
#this shows the graph. In Jupyter this happens automatically after plt.plot, but it's good practice to include it
plt.show()

# %% [markdown]
# This yields an empty plot. <br/>
# This is because we have only told python to show a plot, but we haven't provided it with what to plot and how to plot it.
#
# ---

# %% [markdown]
# ## 4.1. Line Graphs
#
# We can call Matplotlib using plt (since we loaded the library as plt).
# The function to plot line graphs in matplotlib is:
#
# ```
# plt.plot(x_values, y_values)
# ```
#
# Matplotlib will accept any iterable object, like NumPy arrays and pandas.Series instances as input for a line graph.
#
# ### Assignment 4: Generating Line Graphs
#
# We will now generate two line graphs for the year 1991 using two different statistics.
#
# * Generate a line graph for the year 1991 that shows the date on the x-axis and the length of the articles on the y-axis
# * Generate a line graph for the year 1991 that shows the date on the x-axis and the mean number of words in the articles on the y-axis
#
# __Tip__:
#
# * Remember we set the date as the index. You can access the index using ```df.index```
# * You can select a year using ```df['1966']```
# * To select the index for a particular year you need to type ```df['1966'].index```
# * To select a particular column in a year you can use ```df['1996']['newspaper_title']```
# * Remember to always close with ```plt.show()```

# %%
plt.plot( df['1991'].index, df['1991']['mean_article_length'])
plt.plot( df['1991'].index, df['1991']['mean_number_of_words'])
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# The x-axis for the graph we generated is not very readable.
# One way to fix this is to turn the labels on the x-axis.
# We can do this with the xticks function.
#
# ```
# matplotlib.pyplot.xticks()
# ```
# Graphing includes a lot of Googling and reading documentation.
# Try and see if you can figure out how to rotate the xticks here: http://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.xticks

# %% [markdown]
# ### Assignment 5
# * Generate a line graph for 1991 that shows the __date__ on the x-axis and the __mean length of the articles__ on the y-axis.
# * But also rotate the x-axis with __90 degrees__.
# * Reflect on what the graph shows us and note this down in a Markdown cell.

# %% [markdown]
# ### Make the graph a little fancier
# We still need to add labels to the x-axis and the y-axis, and we need to give the graph a title.
# * To set the x-axis label we can pass a string to the function: ```xlabel()```
# * For the y-axis label, pass a string value to: ```ylabel()```
# * To give the graph a title pass a string value to: ```title()```
# * You can also give your graph a style using ```plt.style.use()```
#
# For an overview of the styles see: https://tonysyu.github.io/raw_content/matplotlib-style-gallery/gallery.html
#
# __Tip__: To call a function for matplotlib use ```plt.xlabel()```
#
# ### Assignment 6###
#
# * Generate a line graph for 1991 that plots the mean length of the articles.
# * Rotate the labels
# * Give the graph a title
# * Label the x-axis and y-axis.
#
# __Tip__: You can copy parts of your earlier code

# %%
plt.plot( df['1991'].index, df['1991']['mean_article_length'])
plt.xticks(rotation=45)
plt.xlabel('date_of_1991')
plt.ylabel('mean_length_of_the_articles')
plt.title('mean length of the articles in 1991')
plt.style.use('dark_background')
plt.show()

# %% [markdown]
# ### The Elements of the Graph
#
# There are two central elements, the __Figure__ object and the __Axes__ object.
#
#
# The Figure object is container and contains the entire visualization.
# One Figure can, for instance, include multiple graphs.
# You can initialize a figure using:
# ```
# fig = plt.figure()
# ```
# The Axes object contains the information that is used to plot the graph within a Figure.
# An Axes object holds:
# * the values,
# * ticks on the x-axis and y-axis,
# * and visual symbols such as markers, lines, and gridlines.
#
# A Figure object can contain multiple Axes objects, that is multiple line graphs in one Figure.
#
# You can create an Axes object using:
# ```
# axes_obj = fig.add_subplot(nrows, ncols, plot_number)
# ```
# If you wanted to plot two graphs next to each other. You would use:
# ```
# ax1 = fig.add_subplot(2,1,1)
# ax2 = fig.add_subplot(2,1,2)
# ```

# %% [markdown]
# ### Assignment 7: Making Axes and Figures
#
# Create an empty Figure that contains four Axes objects positioned in 2 rows and 2 columns.
# * First make the Figure object
# * Then add four Axes objects
# * Specify where to position the Axes objects

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)
ax4 = fig.add_subplot(2,2,4)
plt.tight_layout(pad=0.4, w_pad=0.5, h_pad=1.0)
ax1.plot( df['1991'].index, df['1991']['mean_article_length'])
ax2.plot( df['1991'].index, df['1991']['mean_number_of_words'])
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# These graphs could use a little padding between them.
# To increase the padding between them you can add to the previous block.
# Add this and play around with the values.
# ```
# plt.tight_layout(pad=0.4, w_pad=0.5, h_pad=1.0)
#
# ```

# %% [markdown]
# ---

# %% [markdown]
# ### Assignment 8: Making Graphs with Real Data
#
# We are now going to fill the Axes objects with actual data.
# * Make a figure that contains two subplots (Axes Objects) underneath each other.
# * Show a line graph with the mean number of words in 1966 and another one for 1991.
#
# __Tip__ You need to call the plot function on the Ax object:
# ```
# ax.plot(x_values, y_values)
# ```

# %% [markdown]
# ---

# %% [markdown]
# As you can see the second graph does not fit within the image.
# One way to solve this is to increase the size of the entire Figure object.
# You can do this with:
# ```
# fig = plt.figure(figsize=(width, height))
# ```
# Adjust the previous block and set a width and height that works for you.

# %% [markdown]
# ### Assignment 9: Multiple line graphs in one figure
#
# Of course you also plot multiple line graphs into one figure.
# * Plot a graph that shows the mean number of words for 1939, 1966, and 1991 into one figure
# * You need to repeat the ```plt.plot``` function three times
# * Think about which variable you want to use for the x-axis. The date index or the 'day' column

# %%
plt.plot( df['1939']['day'], df['1939']['mean_number_of_words'], c = 'green', label = 'mean_number_of_words_1939')
plt.plot( df['1966']['day'], df['1966']['mean_number_of_words'], c = 'white', label = 'mean_number_of_words_1966')
plt.plot( df['1991']['day'], df['1991']['mean_number_of_words'], c = 'yellow',label = 'mean_number_of_words_1991')
plt.legend(loc='best')

# %% [markdown]
# Python automatically assigns colors to the different line graphs.
# If you don't like these colors you can add the parameter.
# ```
# c = 'name of colour'
# ```
#
# You can also add labels to the lines with the parameter
# ```
# label = 'name of label'
# ```
# If you want to add a legend you add the line. Feel free to change the value.
# ```
# plt.legend(loc='upperleft')
# ```

# %% [markdown]
# ### Assignment 10: Add colors, labels, a title, and a legend to the chart from Assignment 9
# * copy the code from assignment 9
# * add a title
# * add color for each line graph
# * add a label that indicates the year
# * add a legend

# %% [markdown]
# ---

# %% [markdown]
# ## 4.2. Bar Chart
#
# In addition to line graphs, an often used visualization is the bar graph.
# To bee able to create a bar chart, we need to tell Python a couple of things:
# * the position of the individual bars
# * the width of the bars
# * position of the labels
#
# We will use the ```ax.bar(bar_positions, bar_heights, width)``` method, this allows for a lot of customization of the visuals.
#
# The __bar_positions__ parameter determines the where we place the left side of the bar on the x-axis.
# The __bar_heights__ parameter is used for the height of the bar.
# The __width__ parameter determines the widht of the bar.
#
# These parameters need multiple values in the form of a list [10, 20, 30]

# %% [markdown]
# ### Bar Position
#
# To space the bars in evenly distributed spaces, we use the following function:
# ```
# np.arange()
# ```
# This numpy function returns evenly spaces values in the form of a list.
# For instance
# ```np.arange(5)``` returns ```[0,1,2,3,4]```

# %%
bar_positions = np.arange(3)

# %% [markdown]
# ### Bar Height
# For the height of the bears we will calculate the number of articles per year.

# %%
bar_heights = df['year'].value_counts().sort_index()

# %% [markdown]
# ### Assignment 11: Making a bar graph
# * first initialize a Figure and Axes object using ```fig,ax = plt.subplots()```
# * Then use the bar function on the Axes object with a width of .5, and the variables bar_positions and bar_heights

# %% [markdown]
# This graph contains 5 tick marks.
# We actually want the tickmarks on the x-axis to correspond to our years.
# You can set the number of tick marks by passing a list to ```ax.set_xticks(range(0,3))```
# In this case the number of tickmarks correspond to the number of number of bars.
# So we could also pass the variable bar_positions.
#
# ### Assignment 12: Add visual aids to bar graph.
# * copy the code from the previous bar chart
# * give the bar chart a title
# * give the x and y-axis a label
# * set the number of tickmarks
# * give the bar charts individual labels using ```ax.set.xticklabels()```

# %% [markdown]
# ---

# %% [markdown]
# This might seem like a lot of work for a simple bar chart.
# However, you can reuse parts of existing code and you are also able to fully customize your bar chart.
# With libraries such as Pandas and Seaborn you can generate template bar charts in a less verbose manner.

# %% [markdown]
# ## 4.3. Histogram
# We use histograms to visualize the distribution of quantitative data.
# This can help us analayze how the length of articles is distributed in a dataset.
# With bar charts, the number of bars corresponds to the categorical data (for example, men vs women).
#
# In the case of a histogram we need to define in how many bars (_bins_) we want to divide our data.
# If we do not define this Matplotlib determines this.
#
# You can create a histogram with the function
# ```
# plt.hist(x, bins, range)
# ```
# * x = the input value
# * bins = the number of bins
# * range = the upper and lower range of the bins

# %% [markdown]
# ### Assignment 13: Make a histogram
# Generate a histogram for the column 'article_length'. Do not fill out the bins and range parameters yet.

# %% [markdown]
# ---

# %% [markdown]
# As you can see most articles contain less than 25,000 characters.
# This set of articles are all grouped into two bins.
# The articles with very high values are probably outliers.
#
# Let's increase the number of bins and also set the range.
# This makes it easier for us to zoom in on the distribution.
# Play around with these values and see what happens.

# %% [markdown]
# ### Assignment 14: Making multiple histograms
# For this assignment we will plot three histograms of the column article length for the years 1939, 1966, and 1991.
#
# * initialize the Figure object and give the graph a size
# * initialize three Axes Objects and places them next to each other or underneath each other
# * Call the hist function on each ax object and set the number of bins and the range.
# * Also set an x and y label for each of the ax objects
# * You can give the entire Figure a title with ```fig.suptitle("Three Histograms")```

# %% [markdown]
# ## Saving a Graph
# If you want to save a graph as a file. You can call the function ``savefig`` on your Figure object.
# For example,
#
# ```
# fig.savefig('test.png', bbox_inches='tight', dpi=300)
# ```
#
# The first parameter defines the name and file format, the second the padding around the image, and the last the number of dots-per-inch.

# %% [markdown]
# ## Further Exploration
#
# Other forms of visualization include __boxplots__ and __scatterplots__.
#
# You can study the Matplotlib documentation to learn more about this visualization.
# It follows the same logic as the previous examples.
# For instance, a boxplot is called through ```ax.boxplot``` and a scatterplot with ```ax.scatter```.
#
# ---

# %% [markdown]
# ## 5. Plotting with Pandas
# For the final part of this workshop, we will use Pandas to do our plotting.
# This is often easier than using Matplotlib.
# Plotting with Pandas relies on Matplotlib.
# For this reason, we can always customize element produced by Pandas through matplotlib using the
# knowledge you gained in previous assingments.
#
# Plotting with Pandas relies on Matplotlib. It's done via the function
# ```
# dataframe.plot()
# ```
# We can pass the x and y-value, the kind of plot, the title and the figsize in one line.
# For instance:
# ```
# df['1991'].plot(x='day', y='mean_size', kind='line', title='Mean size per day', figsize=(5,10))
# ```
# More on this see: http://pandas.pydata.org/pandas-docs/version/0.19.0/generated/pandas.DataFrame.plot.html

# %% [markdown]
# ---

# %% [markdown]
# ### Assingment 15: Plotting with Pandas
#
# Try to plot a green line graph for the year 1966 with the 'day' column as the x-axis, mean_article_length as the y-axis and give the line the label '1966'.

# %% [markdown]
# If you assign the pandas plot to a variable (for instance 'ax'), you can override the graph using the matplotlib functions you learned.
# * Assign the pandas plot to a variable
# * Change the limit of the y-axis, and the title of the graph.
#
# __Tip__:
# * You can change the limit of the y-axis by calling the function set_ylim() on your Axes object

# %% [markdown]
# ---

# %% [markdown]
# ### Assignment 16: Generate the same three histograms as in Assignment 14 using Pandas

# %% [markdown]
# ---

# %% [markdown]
# ### Further reading/exploration
# Edward Tufte's book 'The visual display of quantitative information'.
# Also see Bokeh and Seaborn for many more plotting options.
#
# * https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.plot.html
# * https://pandas.pydata.org/pandas-docs/stable/visualization.html
# * https://matplotlib.org
# * https://seaborn.pydata.org
# * http://bokeh.pydata.org/en/latest
